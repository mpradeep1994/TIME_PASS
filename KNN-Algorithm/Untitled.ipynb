# %%
import csv
import random
import math
import operator



def euclideanDistance(instance1, instance2, length):
    distance = 0
    for x in range(length):
        distance += pow((float(instance1[x]) - float(instance2[x])), 2)
    return math.sqrt(distance)

def getNeighbors(trainingSet, testInstance, k):
	distances = []
	length = len(testInstance)-1
	for x in range(len(trainingSet)):
		dist = euclideanDistance(testInstance, trainingSet[x], length)
		distances.append((trainingSet[x], dist))
        print "test",testInstance, "train",trainingSet[x],dist
        
	distances.sort(key=operator.itemgetter(1))
	neighbors = []
	for x in range(k):
		neighbors.append(distances[x][0])
	return neighbors

def getResponse(neighbors):
	classVotes = {}
	for x in range(len(neighbors)):
		response = neighbors[x][-1]
		if response in classVotes:
			classVotes[response] += 1
		else:
			classVotes[response] = 1
	sortedVotes = sorted(classVotes.iteritems(), key=operator.itemgetter(1), reverse=True)
	return sortedVotes[0][0]

def getAccuracy(testSet, predictions):
	correct = 0
	for x in range(len(testSet)):
		if testSet[x][-1] == predictions[x]:
			correct += 1
	return (correct/float(len(testSet))) * 100.0
	
def main():
    filename = 'test.txt'
    results=[]
    with open(filename) as inputfile:
        for line in inputfile:
            results.append(line.strip().split(','))
    testSet = results
    filename = 'train.txt'
    with open(filename) as inputfile:
        for line in inputfile:
            results.append(line.strip().split(','))

    trainingSet = results   

    predictions=[]
    k = 3
    
    for x in range(len(testSet)):
        neighbors = getNeighbors(trainingSet, testSet[x], k)
        result = getResponse(neighbors)
        predictions.append(result)
        #print('> predicted=' + repr(result) + ', actual=' + repr(testSet[x][-1]))
    accuracy = getAccuracy(testSet, predictions)
    print('Accuracy: ' + repr(accuracy) + '%')
    
main()
# Out:
# test ['4.8', '3.1', '1.6', '0.2', 'Iris-setosa'] train ['5.9', '3.0', '5.1', '1.8', 'Iris-virginica'] 4.00374824383
# test ['5.4', '3.4', '1.5', '0.4', 'Iris-setosa'] train ['5.9', '3.0', '5.1', '1.8', 'Iris-virginica'] 3.91535439009
# test ['5.2', '4.1', '1.5', '0.1', 'Iris-setosa'] train ['5.9', '3.0', '5.1', '1.8', 'Iris-virginica'] 4.18927201313
# test ['5.5', '4.2', '1.4', '0.2', 'Iris-setosa'] train ['5.9', '3.0', '5.1', '1.8', 'Iris-virginica'] 4.22492603486
# test ['4.9', '3.1', '1.5', '0.1', 'Iris-setosa'] train ['5.9', '3.0', '5.1', '1.8', 'Iris-virginica'] 4.10609303353
# test ['5.0', '3.2', '1.2', '0.2', 'Iris-setosa'] train ['5.9', '3.0', '5.1', '1.8', 'Iris-virginica'] 4.31508980208
# test ['5.5', '3.5', '1.3', '0.2', 'Iris-setosa'] train ['5.9', '3.0', '5.1', '1.8', 'Iris-virginica'] 4.17252920901
# test ['4.9', '3.1', '1.5', '0.1', 'Iris-setosa'] train ['5.9', '3.0', '5.1', '1.8', 'Iris-virginica'] 4.10609303353
# test ['4.4', '3.0', '1.3', '0.2', 'Iris-setosa'] train ['5.9', '3.0', '5.1', '1.8', 'Iris-virginica'] 4.3874821937
# test ['5.1', '3.4', '1.5', '0.2', 'Iris-setosa'] train ['5.9', '3.0', '5.1', '1.8', 'Iris-virginica'] 4.03980197534
# test ['5.0', '3.5', '1.3', '0.3', 'Iris-setosa'] train ['5.9', '3.0', '5.1', '1.8', 'Iris-virginica'] 4.21307488659
# test ['4.5', '2.3', '1.3', '0.3', 'Iris-setosa'] train ['5.9', '3.0', '5.1', '1.8', 'Iris-virginica'] 4.37492857085
# test ['4.4', '3.2', '1.3', '0.2', 'Iris-setosa'] train ['5.9', '3.0', '5.1', '1.8', 'Iris-virginica'] 4.3920382512
# test ['5.0', '3.5', '1.6', '0.6', 'Iris-setosa'] train ['5.9', '3.0', '5.1', '1.8', 'Iris-virginica'] 3.84057287393
# test ['5.1', '3.8', '1.9', '0.4', 'Iris-setosa'] train ['5.9', '3.0', '5.1', '1.8', 'Iris-virginica'] 3.67151195014
# test ['4.8', '3.0', '1.4', '0.3', 'Iris-setosa'] train ['5.9', '3.0', '5.1', '1.8', 'Iris-virginica'] 4.14125584817
# test ['5.1', '3.8', '1.6', '0.2', 'Iris-setosa'] train ['5.9', '3.0', '5.1', '1.8', 'Iris-virginica'] 4.01123422403
# test ['4.6', '3.2', '1.4', '0.2', 'Iris-setosa'] train ['5.9', '3.0', '5.1', '1.8', 'Iris-virginica'] 4.24028300942
# test ['5.3', '3.7', '1.5', '0.2', 'Iris-setosa'] train ['5.9', '3.0', '5.1', '1.8', 'Iris-virginica'] 4.04598566483
# test ['5.0', '3.3', '1.4', '0.2', 'Iris-setosa'] train ['5.9', '3.0', '5.1', '1.8', 'Iris-virginica'] 4.14125584817
# test ['5.8', '2.7', '3.9', '1.2', 'Iris-versicolor'] train ['5.9', '3.0', '5.1', '1.8', 'Iris-virginica'] 1.37840487521
# test ['6.0', '2.7', '5.1', '1.6', 'Iris-versicolor'] train ['5.9', '3.0', '5.1', '1.8', 'Iris-virginica'] 0.374165738677
# test ['5.4', '3.0', '4.5', '1.5', 'Iris-versicolor'] train ['5.9', '3.0', '5.1', '1.8', 'Iris-virginica'] 0.836660026534
# test ['6.0', '3.4', '4.5', '1.6', 'Iris-versicolor'] train ['5.9', '3.0', '5.1', '1.8', 'Iris-virginica'] 0.754983443527
# test ['6.7', '3.1', '4.7', '1.5', 'Iris-versicolor'] train ['5.9', '3.0', '5.1', '1.8', 'Iris-virginica'] 0.948683298051
# test ['6.3', '2.3', '4.4', '1.3', 'Iris-versicolor'] train ['5.9', '3.0', '5.1', '1.8', 'Iris-virginica'] 1.17898261226
# test ['5.6', '3.0', '4.1', '1.3', 'Iris-versicolor'] train ['5.9', '3.0', '5.1', '1.8', 'Iris-virginica'] 1.15758369028
# test ['5.5', '2.5', '4.0', '1.3', 'Iris-versicolor'] train ['5.9', '3.0', '5.1', '1.8', 'Iris-virginica'] 1.36747943312
# test ['5.5', '2.6', '4.4', '1.2', 'Iris-versicolor'] train ['5.9', '3.0', '5.1', '1.8', 'Iris-virginica'] 1.08166538264
# test ['6.1', '3.0', '4.6', '1.4', 'Iris-versicolor'] train ['5.9', '3.0', '5.1', '1.8', 'Iris-virginica'] 0.67082039325
# test ['5.8', '2.6', '4.0', '1.2', 'Iris-versicolor'] train ['5.9', '3.0', '5.1', '1.8', 'Iris-virginica'] 1.31909059583
# test ['5.0', '2.3', '3.3', '1.0', 'Iris-versicolor'] train ['5.9', '3.0', '5.1', '1.8', 'Iris-virginica'] 2.27596133535
# test ['5.6', '2.7', '4.2', '1.3', 'Iris-versicolor'] train ['5.9', '3.0', '5.1', '1.8', 'Iris-virginica'] 1.11355287257
# test ['5.7', '3.0', '4.2', '1.2', 'Iris-versicolor'] train ['5.9', '3.0', '5.1', '1.8', 'Iris-virginica'] 1.1
# test ['5.7', '2.5', '5.0', '2.0', 'Iris-virginica'] train ['5.9', '3.0', '5.1', '1.8', 'Iris-virginica'] 0.583095189485
# test ['5.8', '2.8', '5.1', '2.4', 'Iris-virginica'] train ['5.9', '3.0', '5.1', '1.8', 'Iris-virginica'] 0.640312423743
# test ['6.4', '3.2', '5.3', '2.3', 'Iris-virginica'] train ['5.9', '3.0', '5.1', '1.8', 'Iris-virginica'] 0.761577310586
# test ['6.5', '3.0', '5.5', '1.8', 'Iris-virginica'] train ['5.9', '3.0', '5.1', '1.8', 'Iris-virginica'] 0.721110255093
# test ['7.7', '3.8', '6.7', '2.2', 'Iris-virginica'] train ['5.9', '3.0', '5.1', '1.8', 'Iris-virginica'] 2.56904651573
# test ['7.7', '2.6', '6.9', '2.3', 'Iris-virginica'] train ['5.9', '3.0', '5.1', '1.8', 'Iris-virginica'] 2.62488094968
# test ['6.0', '2.2', '5.0', '1.5', 'Iris-virginica'] train ['5.9', '3.0', '5.1', '1.8', 'Iris-virginica'] 0.866025403784
# test ['6.9', '3.2', '5.7', '2.3', 'Iris-virginica'] train ['5.9', '3.0', '5.1', '1.8', 'Iris-virginica'] 1.28452325787
# test ['5.6', '2.8', '4.9', '2.0', 'Iris-virginica'] train ['5.9', '3.0', '5.1', '1.8', 'Iris-virginica'] 0.458257569496
# test ['7.7', '2.8', '6.7', '2.0', 'Iris-virginica'] train ['5.9', '3.0', '5.1', '1.8', 'Iris-virginica'] 2.4248711306
# test ['6.3', '2.7', '4.9', '1.8', 'Iris-virginica'] train ['5.9', '3.0', '5.1', '1.8', 'Iris-virginica'] 0.538516480713
# test ['6.7', '3.3', '5.7', '2.1', 'Iris-virginica'] train ['5.9', '3.0', '5.1', '1.8', 'Iris-virginica'] 1.08627804912
# test ['7.2', '3.2', '6.0', '1.8', 'Iris-virginica'] train ['5.9', '3.0', '5.1', '1.8', 'Iris-virginica'] 1.59373774505
# test ['6.2', '2.8', '4.8', '1.8', 'Iris-virginica'] train ['5.9', '3.0', '5.1', '1.8', 'Iris-virginica'] 0.469041575982
# test ['6.1', '3.0', '4.9', '1.8', 'Iris-virginica'] train ['5.9', '3.0', '5.1', '1.8', 'Iris-virginica'] 0.282842712475
# test ['6.4', '2.8', '5.6', '2.1', 'Iris-virginica'] train ['5.9', '3.0', '5.1', '1.8', 'Iris-virginica'] 0.793725393319
# test ['7.2', '3.0', '5.8', '1.6', 'Iris-virginica'] train ['5.9', '3.0', '5.1', '1.8', 'Iris-virginica'] 1.48996644258
# test ['7.4', '2.8', '6.1', '1.9', 'Iris-virginica'] train ['5.9', '3.0', '5.1', '1.8', 'Iris-virginica'] 1.81659021246
# test ['7.9', '3.8', '6.4', '2.0', 'Iris-virginica'] train ['5.9', '3.0', '5.1', '1.8', 'Iris-virginica'] 2.52388589282
# test ['6.4', '2.8', '5.6', '2.2', 'Iris-virginica'] train ['5.9', '3.0', '5.1', '1.8', 'Iris-virginica'] 0.836660026534
# test ['6.3', '2.8', '5.1', '1.5', 'Iris-virginica'] train ['5.9', '3.0', '5.1', '1.8', 'Iris-virginica'] 0.538516480713
# test ['6.1', '2.6', '5.6', '1.4', 'Iris-virginica'] train ['5.9', '3.0', '5.1', '1.8', 'Iris-virginica'] 0.781024967591
# test ['7.7', '3.0', '6.1', '2.3', 'Iris-virginica'] train ['5.9', '3.0', '5.1', '1.8', 'Iris-virginica'] 2.11896201004
# test ['6.3', '3.4', '5.6', '2.4', 'Iris-virginica'] train ['5.9', '3.0', '5.1', '1.8', 'Iris-virginica'] 0.964365076099
# test ['6.4', '3.1', '5.5', '1.8', 'Iris-virginica'] train ['5.9', '3.0', '5.1', '1.8', 'Iris-virginica'] 0.648074069841
# test ['5.1', '3.5', '1.4', '0.2', 'Iris-setosa'] train ['5.9', '3.0', '5.1', '1.8', 'Iris-virginica'] 4.1400483089
# test ['4.9', '3.0', '1.4', '0.2', 'Iris-setosa'] train ['5.9', '3.0', '5.1', '1.8', 'Iris-virginica'] 4.15331193146
# test ['4.7', '3.2', '1.3', '0.2', 'Iris-setosa'] train ['5.9', '3.0', '5.1', '1.8', 'Iris-virginica'] 4.29883705204
# test ['4.6', '3.1', '1.5', '0.2', 'Iris-setosa'] train ['5.9', '3.0', '5.1', '1.8', 'Iris-virginica'] 4.14969878425
# test ['5.0', '3.6', '1.4', '0.2', 'Iris-setosa'] train ['5.9', '3.0', '5.1', '1.8', 'Iris-virginica'] 4.17372735094
# test ['5.4', '3.9', '1.7', '0.4', 'Iris-setosa'] train ['5.9', '3.0', '5.1', '1.8', 'Iris-virginica'] 3.81837661841
# test ['4.6', '3.4', '1.4', '0.3', 'Iris-setosa'] train ['5.9', '3.0', '5.1', '1.8', 'Iris-virginica'] 4.21781934179
# test ['5.0', '3.4', '1.5', '0.2', 'Iris-setosa'] train ['5.9', '3.0', '5.1', '1.8', 'Iris-virginica'] 4.06078810085
# test ['4.4', '2.9', '1.4', '0.2', 'Iris-setosa'] train ['5.9', '3.0', '5.1', '1.8', 'Iris-virginica'] 4.30232495286
# test ['4.9', '3.1', '1.5', '0.1', 'Iris-setosa'] train ['5.9', '3.0', '5.1', '1.8', 'Iris-virginica'] 4.10609303353
# test ['5.4', '3.7', '1.5', '0.2', 'Iris-setosa'] train ['5.9', '3.0', '5.1', '1.8', 'Iris-virginica'] 4.03236903073
# test ['4.8', '3.4', '1.6', '0.2', 'Iris-setosa'] train ['5.9', '3.0', '5.1', '1.8', 'Iris-virginica'] 4.02243707222
# test ['4.8', '3.0', '1.4', '0.1', 'Iris-setosa'] train ['5.9', '3.0', '5.1', '1.8', 'Iris-virginica'] 4.21781934179
# test ['4.3', '3.0', '1.1', '0.1', 'Iris-setosa'] train ['5.9', '3.0', '5.1', '1.8', 'Iris-virginica'] 4.63141447076
# test ['5.8', '4.0', '1.2', '0.2', 'Iris-setosa'] train ['5.9', '3.0', '5.1', '1.8', 'Iris-virginica'] 4.333589736
# test ['5.7', '4.4', '1.5', '0.4', 'Iris-setosa'] train ['5.9', '3.0', '5.1', '1.8', 'Iris-virginica'] 4.11339276024
# test ['5.4', '3.9', '1.3', '0.4', 'Iris-setosa'] train ['5.9', '3.0', '5.1', '1.8', 'Iris-virginica'] 4.17851648316
# test ['5.1', '3.5', '1.4', '0.3', 'Iris-setosa'] train ['5.9', '3.0', '5.1', '1.8', 'Iris-virginica'] 4.10243829935
# test ['5.7', '3.8', '1.7', '0.3', 'Iris-setosa'] train ['5.9', '3.0', '5.1', '1.8', 'Iris-virginica'] 3.80657326213
# test ['5.1', '3.8', '1.5', '0.3', 'Iris-setosa'] train ['5.9', '3.0', '5.1', '1.8', 'Iris-virginica'] 4.06078810085
# test ['5.4', '3.4', '1.7', '0.2', 'Iris-setosa'] train ['5.9', '3.0', '5.1', '1.8', 'Iris-virginica'] 3.81182371051
# test ['5.1', '3.7', '1.5', '0.4', 'Iris-setosa'] train ['5.9', '3.0', '5.1', '1.8', 'Iris-virginica'] 4.0062451248
# test ['4.6', '3.6', '1.0', '0.2', 'Iris-setosa'] train ['5.9', '3.0', '5.1', '1.8', 'Iris-virginica'] 4.62817458616
# test ['5.1', '3.3', '1.7', '0.5', 'Iris-setosa'] train ['5.9', '3.0', '5.1', '1.8', 'Iris-virginica'] 3.73898381917
# test ['4.8', '3.4', '1.9', '0.2', 'Iris-setosa'] train ['5.9', '3.0', '5.1', '1.8', 'Iris-virginica'] 3.76430604494
# test ['5.0', '3.0', '1.6', '0.2', 'Iris-setosa'] train ['5.9', '3.0', '5.1', '1.8', 'Iris-virginica'] 3.95221456907
# test ['5.0', '3.4', '1.6', '0.4', 'Iris-setosa'] train ['5.9', '3.0', '5.1', '1.8', 'Iris-virginica'] 3.89615194776
# test ['5.2', '3.5', '1.5', '0.2', 'Iris-setosa'] train ['5.9', '3.0', '5.1', '1.8', 'Iris-virginica'] 4.03236903073
# test ['5.2', '3.4', '1.4', '0.2', 'Iris-setosa'] train ['5.9', '3.0', '5.1', '1.8', 'Iris-virginica'] 4.11096095822
# test ['4.7', '3.2', '1.6', '0.2', 'Iris-setosa'] train ['5.9', '3.0', '5.1', '1.8', 'Iris-virginica'] 4.03608721412
# test ['7.0', '3.2', '4.7', '1.4', 'Iris-versicolor'] train ['5.9', '3.0', '5.1', '1.8', 'Iris-virginica'] 1.25299640861
# test ['6.4', '3.2', '4.5', '1.5', 'Iris-versicolor'] train ['5.9', '3.0', '5.1', '1.8', 'Iris-virginica'] 0.860232526704
# test ['6.9', '3.1', '4.9', '1.5', 'Iris-versicolor'] train ['5.9', '3.0', '5.1', '1.8', 'Iris-virginica'] 1.0677078252
# test ['5.5', '2.3', '4.0', '1.3', 'Iris-versicolor'] train ['5.9', '3.0', '5.1', '1.8', 'Iris-virginica'] 1.45258390463
# test ['6.5', '2.8', '4.6', '1.5', 'Iris-versicolor'] train ['5.9', '3.0', '5.1', '1.8', 'Iris-virginica'] 0.860232526704
# test ['5.7', '2.8', '4.5', '1.3', 'Iris-versicolor'] train ['5.9', '3.0', '5.1', '1.8', 'Iris-virginica'] 0.830662386292
# test ['6.3', '3.3', '4.7', '1.6', 'Iris-versicolor'] train ['5.9', '3.0', '5.1', '1.8', 'Iris-virginica'] 0.67082039325
# test ['4.9', '2.4', '3.3', '1.0', 'Iris-versicolor'] train ['5.9', '3.0', '5.1', '1.8', 'Iris-virginica'] 2.28910462845
# test ['6.6', '2.9', '4.6', '1.3', 'Iris-versicolor'] train ['5.9', '3.0', '5.1', '1.8', 'Iris-virginica'] 1.0
# test ['5.2', '2.7', '3.9', '1.4', 'Iris-versicolor'] train ['5.9', '3.0', '5.1', '1.8', 'Iris-virginica'] 1.47648230602
# test ['5.0', '2.0', '3.5', '1.0', 'Iris-versicolor'] train ['5.9', '3.0', '5.1', '1.8', 'Iris-virginica'] 2.23830292856
# test ['5.9', '3.0', '4.2', '1.5', 'Iris-versicolor'] train ['5.9', '3.0', '5.1', '1.8', 'Iris-virginica'] 0.948683298051
# test ['6.0', '2.2', '4.0', '1.0', 'Iris-versicolor'] train ['5.9', '3.0', '5.1', '1.8', 'Iris-virginica'] 1.58113883008
# test ['5.7', '2.9', '4.2', '1.3', 'Iris-versicolor'] train ['5.9', '3.0', '5.1', '1.8', 'Iris-virginica'] 1.05356537529
# test ['6.2', '2.9', '4.3', '1.3', 'Iris-versicolor'] train ['5.9', '3.0', '5.1', '1.8', 'Iris-virginica'] 0.994987437107
# test ['5.1', '2.5', '3.0', '1.1', 'Iris-versicolor'] train ['5.9', '3.0', '5.1', '1.8', 'Iris-virginica'] 2.4062418831
# test ['5.7', '2.8', '4.1', '1.3', 'Iris-versicolor'] train ['5.9', '3.0', '5.1', '1.8', 'Iris-virginica'] 1.15325625947
# test ['6.1', '2.9', '4.7', '1.4', 'Iris-versicolor'] train ['5.9', '3.0', '5.1', '1.8', 'Iris-virginica'] 0.60827625303
# test ['5.6', '2.9', '3.6', '1.3', 'Iris-versicolor'] train ['5.9', '3.0', '5.1', '1.8', 'Iris-virginica'] 1.61245154966
# test ['6.7', '3.1', '4.4', '1.4', 'Iris-versicolor'] train ['5.9', '3.0', '5.1', '1.8', 'Iris-virginica'] 1.1401754251
# test ['5.6', '3.0', '4.5', '1.5', 'Iris-versicolor'] train ['5.9', '3.0', '5.1', '1.8', 'Iris-virginica'] 0.734846922835
# test ['5.8', '2.7', '4.1', '1.0', 'Iris-versicolor'] train ['5.9', '3.0', '5.1', '1.8', 'Iris-virginica'] 1.31909059583
# test ['6.2', '2.2', '4.5', '1.5', 'Iris-versicolor'] train ['5.9', '3.0', '5.1', '1.8', 'Iris-virginica'] 1.08627804912
# test ['5.6', '2.5', '3.9', '1.1', 'Iris-versicolor'] train ['5.9', '3.0', '5.1', '1.8', 'Iris-virginica'] 1.50665191733
# test ['5.9', '3.2', '4.8', '1.8', 'Iris-versicolor'] train ['5.9', '3.0', '5.1', '1.8', 'Iris-virginica'] 0.360555127546
# test ['6.1', '2.8', '4.0', '1.3', 'Iris-versicolor'] train ['5.9', '3.0', '5.1', '1.8', 'Iris-virginica'] 1.2409673646
# test ['6.3', '2.5', '4.9', '1.5', 'Iris-versicolor'] train ['5.9', '3.0', '5.1', '1.8', 'Iris-virginica'] 0.734846922835
# test ['6.1', '2.8', '4.7', '1.2', 'Iris-versicolor'] train ['5.9', '3.0', '5.1', '1.8', 'Iris-virginica'] 0.774596669241
# test ['6.4', '2.9', '4.3', '1.3', 'Iris-versicolor'] train ['5.9', '3.0', '5.1', '1.8', 'Iris-virginica'] 1.07238052948
# test ['6.6', '3.0', '4.4', '1.4', 'Iris-versicolor'] train ['5.9', '3.0', '5.1', '1.8', 'Iris-virginica'] 1.0677078252
# test ['6.8', '2.8', '4.8', '1.4', 'Iris-versicolor'] train ['5.9', '3.0', '5.1', '1.8', 'Iris-virginica'] 1.04880884817
# test ['6.7', '3.0', '5.0', '1.7', 'Iris-versicolor'] train ['5.9', '3.0', '5.1', '1.8', 'Iris-virginica'] 0.812403840464
# test ['6.0', '2.9', '4.5', '1.5', 'Iris-versicolor'] train ['5.9', '3.0', '5.1', '1.8', 'Iris-virginica'] 0.68556546004
# test ['5.7', '2.6', '3.5', '1.0', 'Iris-versicolor'] train ['5.9', '3.0', '5.1', '1.8', 'Iris-virginica'] 1.84390889146
# test ['5.5', '2.4', '3.8', '1.1', 'Iris-versicolor'] train ['5.9', '3.0', '5.1', '1.8', 'Iris-virginica'] 1.64316767252
# test ['5.5', '2.4', '3.7', '1.0', 'Iris-versicolor'] train ['5.9', '3.0', '5.1', '1.8', 'Iris-virginica'] 1.76635217327
# test ['6.3', '3.3', '6.0', '2.5', 'Iris-virginica'] train ['5.9', '3.0', '5.1', '1.8', 'Iris-virginica'] 1.2449899598
# test ['5.8', '2.7', '5.1', '1.9', 'Iris-virginica'] train ['5.9', '3.0', '5.1', '1.8', 'Iris-virginica'] 0.331662479036
# test ['7.1', '3.0', '5.9', '2.1', 'Iris-virginica'] train ['5.9', '3.0', '5.1', '1.8', 'Iris-virginica'] 1.47309198627
# test ['6.3', '2.9', '5.6', '1.8', 'Iris-virginica'] train ['5.9', '3.0', '5.1', '1.8', 'Iris-virginica'] 0.648074069841
# test ['6.5', '3.0', '5.8', '2.2', 'Iris-virginica'] train ['5.9', '3.0', '5.1', '1.8', 'Iris-virginica'] 1.00498756211
# test ['7.6', '3.0', '6.6', '2.1', 'Iris-virginica'] train ['5.9', '3.0', '5.1', '1.8', 'Iris-virginica'] 2.28691932521
# test ['4.9', '2.5', '4.5', '1.7', 'Iris-virginica'] train ['5.9', '3.0', '5.1', '1.8', 'Iris-virginica'] 1.27279220614
# test ['7.3', '2.9', '6.3', '1.8', 'Iris-virginica'] train ['5.9', '3.0', '5.1', '1.8', 'Iris-virginica'] 1.84661853126
# test ['6.7', '2.5', '5.8', '1.8', 'Iris-virginica'] train ['5.9', '3.0', '5.1', '1.8', 'Iris-virginica'] 1.17473401245
# test ['7.2', '3.6', '6.1', '2.5', 'Iris-virginica'] train ['5.9', '3.0', '5.1', '1.8', 'Iris-virginica'] 1.88148877222
# test ['6.5', '3.2', '5.1', '2.0', 'Iris-virginica'] train ['5.9', '3.0', '5.1', '1.8', 'Iris-virginica'] 0.663324958071
# test ['6.4', '2.7', '5.3', '1.9', 'Iris-virginica'] train ['5.9', '3.0', '5.1', '1.8', 'Iris-virginica'] 0.62449979984
# test ['6.8', '3.0', '5.5', '2.1', 'Iris-virginica'] train ['5.9', '3.0', '5.1', '1.8', 'Iris-virginica'] 1.0295630141
# test ['6.0', '3.0', '4.8', '1.8', 'Iris-virginica'] train ['5.9', '3.0', '5.1', '1.8', 'Iris-virginica'] 0.316227766017
# test ['6.9', '3.1', '5.4', '2.1', 'Iris-virginica'] train ['5.9', '3.0', '5.1', '1.8', 'Iris-virginica'] 1.09087121146
# test ['6.7', '3.1', '5.6', '2.4', 'Iris-virginica'] train ['5.9', '3.0', '5.1', '1.8', 'Iris-virginica'] 1.12249721603
# test ['6.9', '3.1', '5.1', '2.3', 'Iris-virginica'] train ['5.9', '3.0', '5.1', '1.8', 'Iris-virginica'] 1.12249721603
# test ['5.8', '2.7', '5.1', '1.9', 'Iris-virginica'] train ['5.9', '3.0', '5.1', '1.8', 'Iris-virginica'] 0.331662479036
# test ['6.8', '3.2', '5.9', '2.3', 'Iris-virginica'] train ['5.9', '3.0', '5.1', '1.8', 'Iris-virginica'] 1.31909059583
# test ['6.7', '3.3', '5.7', '2.5', 'Iris-virginica'] train ['5.9', '3.0', '5.1', '1.8', 'Iris-virginica'] 1.256980509
# test ['6.7', '3.0', '5.2', '2.3', 'Iris-virginica'] train ['5.9', '3.0', '5.1', '1.8', 'Iris-virginica'] 0.948683298051
# test ['6.3', '2.5', '5.0', '1.9', 'Iris-virginica'] train ['5.9', '3.0', '5.1', '1.8', 'Iris-virginica'] 0.65574385243
# test ['6.5', '3.0', '5.2', '2.0', 'Iris-virginica'] train ['5.9', '3.0', '5.1', '1.8', 'Iris-virginica'] 0.640312423743
# test ['6.2', '3.4', '5.4', '2.3', 'Iris-virginica'] train ['5.9', '3.0', '5.1', '1.8', 'Iris-virginica'] 0.768114574787
# test ['5.9', '3.0', '5.1', '1.8', 'Iris-virginica'] train ['5.9', '3.0', '5.1', '1.8', 'Iris-virginica'] 0.0
# Accuracy: 96.0%
