# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
header=['name','title','dep','type','salary','hours','annual','rate']
data= pd.read_csv('sal.csv',header=0,names= header)

# %%
data.describe()
# Out:
#              hours
# count  7861.000000
# mean     34.942755
# std       8.641313
# min      10.000000
# 25%      35.000000
# 50%      40.000000
# 75%      40.000000
# max      40.000000

# %%
data.ix[0]
# Out:
# c:\python27\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   """Entry point for launching an IPython kernel.
# name      AARON,  JEFFERY M
# title              SERGEANT
# dep                  POLICE
# type                      F
# salary               Salary
# hours                   NaN
# annual         $101,442.00
# rate                    NaN
# Name: 0, dtype: object

# %%
fp=data.groupby('type').size()
print fp
print fp.index[fp>=2000]
# Out:
# type
# F    30859
# P     1953
# dtype: int64
# Index([u'F'], dtype='object', name=u'type')

# %%
data.rate.fillna(0,inplace=True)
data
# Out:
#                            name  \
# 0             AARON,  JEFFERY M
# 1               AARON,  KARINA
# 2           AARON,  KIMBERLEI R
# 3           ABAD JR,  VICENTE M
# 4            ABARCA,  EMMANUEL
# 5             ABASCAL,  REECE E
# 6         ABBASI,  CHRISTOPHER
# 7         ABBATACOLA,  ROBERT J
# 8            ABBATE,  JOSEPH L
# 9         ABBATEMARCO,  JAMES J
# 10             ABBATE,  TERRY M
# 11             ABBOTT,  BETTY L
# 12             ABDALLAH,  ZAID
# 13       ABDELHADI,  ABDALMAHD
# 14          ABDELLATIF,  AREF R
# 15          ABDELMAJEID,  AZIZ
# 16         ABDOLLAHZADEH,  ALI
# 17     ABDUL-KARIM,  MUHAMMAD A
# 18          ABDULLAH,  DANIEL N
# 19            ABDULLAH,  KEVIN
# 20         ABDULLAH,  LAKENYA N
# 21           ABDULLAH,  RASHAD
# 22        ABDULSATTAR,  MUDHAR
# 23        ABDUL-SHAKUR,  TAHIR
# 24            ABEJERO,  JASON V
# 25      ABERCROMBIE IV,  EARL S
# 26       ABERCROMBIE,  TIMOTHY
# 27           ABFALL,  RICHARD C
# ...

# %%
print data.annual.describe()
data['annual']=data['annual'].map(lambda x: str(x).lstrip('$'))
data['annual']=data.annual.fillna('unknown',inplace = True)
print data.annual
#data['annual'].replace('nan',data.annual.mean())
#data.annual
# Out:
# count           24951
# unique           1017
# top       $90,024.00
# freq             2152
# Name: annual, dtype: object
# 0        None
# 1        None
# 2        None
# 3        None
# 4        None
# 5        None
# 6        None
# 7        None
# 8        None
# 9        None
# 10       None
# 11       None
# 12       None
# 13       None
# 14       None
# 15       None
# 16       None
# 17       None
# 18       None
# 19       None
# 20       None
# 21       None
# 22       None
# 23       None
# 24       None
# 25       None
# 26       None
# 27       None
# 28       None
# 29       None
#          ...
# 32782    None
# 32783    None
# 32784    None
# 32785    None
# 32786    None
# 32787    None
# 32788    None
# 32789    None
# 32790    None
# 32791    None
# 32792    None
# 32793    None
# 32794    None
# 32795    None
# 32796    None
# 32797    None
# 32798    None
# 32799    None
# 32800    None
# 32801    None
# 32802    None
# 32803    None
# 32804    None
# ...

# %%
d=pd.pivot_table(data,index='dep',values='salary')
# Out:
# ---------------------------------------------------------------------------
# DataError                                 Traceback (most recent call last)
# <ipython-input-152-e61257a5f32b> in <module>()
# ----> 1 d=pd.pivot_table(data,index='dep',values='salary')
#
# c:\python27\lib\site-packages\pandas\core\reshape\pivot.pyc in pivot_table(data, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name)
#      80
#      81     grouped = data.groupby(keys)
# ---> 82     agged = grouped.agg(aggfunc)
#      83
#      84     table = agged
#
# c:\python27\lib\site-packages\pandas\core\groupby.pyc in aggregate(self, arg, *args, **kwargs)
#    4187         versionadded=''))
#    4188     def aggregate(self, arg, *args, **kwargs):
# -> 4189         return super(DataFrameGroupBy, self).aggregate(arg, *args, **kwargs)
#    4190
#    4191     agg = aggregate
#
# c:\python27\lib\site-packages\pandas\core\groupby.pyc in aggregate(self, arg, *args, **kwargs)
#    3620
# ...

# %%
DataFrame=np.random.normal(100,500,10)
n.hist(bins=4)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-241-f4129abe190e> in <module>()
#       1 DataFrame=np.random.normal(100,500,10)
# ----> 2 n.hist(bins=4)
#
# AttributeError: 'numpy.ndarray' object has no attribute 'hist'

# %%
da=data.groupby(by=['dep'])
import numpy as np
da=data.groupby(level=0).agg({'rate': np.sum})

# %%
data.boxplot(column='rate')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-250-c777ecf0832e> in <module>()
# ----> 1 data.boxplot(column='rate')
#
# c:\python27\lib\site-packages\pandas\plotting\_core.pyc in boxplot_frame(self, column, by, ax, fontsize, rot, grid, figsize, layout, return_type, **kwds)
#    2063     ax = boxplot(self, column=column, by=by, ax=ax, fontsize=fontsize,
#    2064                  grid=grid, rot=rot, figsize=figsize, layout=layout,
# -> 2065                  return_type=return_type, **kwds)
#    2066     plt.draw_if_interactive()
#    2067     return ax
#
# c:\python27\lib\site-packages\pandas\plotting\_core.pyc in boxplot(data, column, by, ax, fontsize, rot, grid, figsize, layout, return_type, **kwds)
#    2047             columns = data.columns
#    2048         else:
# -> 2049             data = data[columns]
#    2050
# ...

# %%
data.annual.hist(bins=100)
plt.show()

# %%
left = pd.DataFrame({'key': ['foo', 'bar','asd'], 'val': [1, 50,3]}).set_index('key')
right = pd.DataFrame({'key': ['foo', 'bar'], 'val': [6, 50]}).set_index('key')
#left.join(right, lsuffix='_l', rsuffix='_r')
left.reset_index(inplace=True)
right.reset_index(inplace=True)

# %%
join=pd.merge(left,right,on=['key'],how='inner')
join.set_index('key',inplace=True)
print join
# Out:
#      val_x  val_y
# key
# foo      1      6
# bar     50     50

# %%
join.corr()
# Out:
#        val_x  val_y
# val_x    1.0    1.0
# val_y    1.0    1.0

# %%
join['val_x'].resample('A',how='mean')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-200-0617a8b4b56b> in <module>()
# ----> 1 join['val_x'].resample('A',how='mean')
#
# c:\python27\lib\site-packages\pandas\core\generic.pyc in resample(self, rule, how, axis, fill_method, closed, label, convention, kind, loffset, limit, base, on, level)
#    5520                      axis=axis, kind=kind, loffset=loffset,
#    5521                      convention=convention,
# -> 5522                      base=base, key=on, level=level)
#    5523         return _maybe_process_deprecations(r,
#    5524                                            how=how,
#
# c:\python27\lib\site-packages\pandas\core\resample.pyc in resample(obj, kind, **kwds)
#     982     """ create a TimeGrouper and return our resampler """
#     983     tg = TimeGrouper(**kwds)
# --> 984     return tg._get_resampler(obj, kind=kind)
#     985
# ...

# %%
data.boxplot(column="rate")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-249-6062fc46e5d9> in <module>()
# ----> 1 data.boxplot(column="rate")
#
# c:\python27\lib\site-packages\pandas\plotting\_core.pyc in boxplot_frame(self, column, by, ax, fontsize, rot, grid, figsize, layout, return_type, **kwds)
#    2063     ax = boxplot(self, column=column, by=by, ax=ax, fontsize=fontsize,
#    2064                  grid=grid, rot=rot, figsize=figsize, layout=layout,
# -> 2065                  return_type=return_type, **kwds)
#    2066     plt.draw_if_interactive()
#    2067     return ax
#
# c:\python27\lib\site-packages\pandas\plotting\_core.pyc in boxplot(data, column, by, ax, fontsize, rot, grid, figsize, layout, return_type, **kwds)
#    2047             columns = data.columns
#    2048         else:
# -> 2049             data = data[columns]
#    2050
# ...

# %%
df1=data.copy()

# %%
#correct
rep={',':'',
     '.00':'',
     '$':''}
df1.annual=df1.annual.astype(str)
df1['annual'] = df1.annual.replace(rep)
df1.annual = pd.to_numeric(df1.annual, errors='coerce')
df1.annual.fillna(df1.annual.mean(), inplace=True)
df1.annual=df1.annual.astype(int)
#print data.annual.head()
#print  df1
#df1['annual'] = df1['annual']

# %%
df1.annual.hist(bins=50)
plt.show()

# %%
#log transform
df1.annual = np.log(df1.annual)
df1.annual.hist(bins=10)
plt.show()

# %%
print(df1.isnull().values.any())
print(df1.isnull().values.any())
# Out:
# True
# True

# %%
df1.columns[df1.isnull().any()].tolist()
# Out:
# ['hours', 'rate']

# %%
df1.boxplot(column='annual')
plt.show()

# %%
df1.boxplot(column='annual')
df1.boxplot(column='annual', by=['type'])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-14bb7aa435f0> in <module>()
# ----> 1 df1.boxplot(column='annual')
#       2 df1.boxplot(column='annual', by=['type'])
#       3 plt.show()
#
# NameError: name 'df1' is not defined

# %%
df1.apply(lambda x: sum(x.isnull()),axis=0)
# Out:
# name          0
# title         0
# dep           0
# type          0
# salary        0
# hours     24951
# annual        0
# rate      24951
# dtype: int64

# %%
x=[1,3,4,5,4,4,3,2,2]
y=[2,3,2,2,1,1,1,1,1]
from sklearn.cross_validation import train_test_split 
from sklearn.cross_validation import KFold

# %%
a,b,c,d =train_test_split(x,y)

# %%
print a,b,c,d
# Out:
# [4, 4, 2, 4, 1, 2] [5, 3, 3] [1, 2, 1, 1, 2, 1] [2, 1, 3]

# %%
kf= KFold(len(x),n_folds=5)

# %%
for i,j in kf:
    print data.iloc[i,:]
    print data.iloc[j]
# Out:
#                     name                        title               dep type  \
# 2    AARON,  KIMBERLEI R     CHIEF CONTRACT EXPEDITER  GENERAL SERVICES    F
# 3    ABAD JR,  VICENTE M            CIVIL ENGINEER IV       WATER MGMNT    F
# 4     ABARCA,  EMMANUEL              CONCRETE LABORER        TRANSPORTN    F
# 5      ABASCAL,  REECE E  TRAFFIC CONTROL AIDE-HOURLY              OEMC    P
# 6  ABBASI,  CHRISTOPHER    STAFF ASST TO THE ALDERMAN      CITY COUNCIL    F
# 7  ABBATACOLA,  ROBERT J          ELECTRICAL MECHANIC          AVIATION    F
# 8     ABBATE,  JOSEPH L       POOL MOTOR TRUCK DRIVER     STREETS & SAN    F
#
#    salary  hours    annual     rate
# 2  Salary    NaN  101592.0      NaN
# 3  Salary    NaN  110064.0      NaN
# 4  Hourly   40.0       NaN  $36.18
# 5  Hourly   20.0       NaN  $19.86
# 6  Salary    NaN   50436.0      NaN
# 7  Hourly   40.0       NaN  $46.10
# 8  Hourly   40.0       NaN  $35.60
# ...

# %%
data.iloc[i,:]
# Out:
#                     name                                   title  \
# 0      AARON,  JEFFERY M                                SERGEANT
# 1        AARON,  KARINA   POLICE OFFICER (ASSIGNED AS DETECTIVE)
# 2    AARON,  KIMBERLEI R                CHIEF CONTRACT EXPEDITER
# 3    ABAD JR,  VICENTE M                       CIVIL ENGINEER IV
# 4     ABARCA,  EMMANUEL                         CONCRETE LABORER
# 5      ABASCAL,  REECE E             TRAFFIC CONTROL AIDE-HOURLY
# 6  ABBASI,  CHRISTOPHER               STAFF ASST TO THE ALDERMAN
# 7  ABBATACOLA,  ROBERT J                     ELECTRICAL MECHANIC
#
#                 dep type  salary  hours    annual     rate
# 0            POLICE    F  Salary    NaN  101442.0      NaN
# 1            POLICE    F  Salary    NaN   94122.0      NaN
# 2  GENERAL SERVICES    F  Salary    NaN  101592.0      NaN
# 3       WATER MGMNT    F  Salary    NaN  110064.0      NaN
# 4        TRANSPORTN    F  Hourly   40.0       NaN  $36.18
# ...

# %%
pd.scatter_matrix(df1.corr(), figsize=(6, 6))
plt.show()
# Out:
# c:\python27\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: pandas.scatter_matrix is deprecated. Use pandas.plotting.scatter_matrix instead
#   """Entry point for launching an IPython kernel.

# %%
import matplotlib
#matplotlib.style.use('ggplot')

plt.scatter(x, y)
plt.show()

# %%
data.annual.fillna(data.annual.mean(), inplace=True)
print data.annual
# Out:
# 0        101442.000000
# 1         94122.000000
# 2        101592.000000
# 3        110064.000000
# 4         87313.959187
# 5         87313.959187
# 6         50436.000000
# 7         87313.959187
# 8         87313.959187
# 9        103350.000000
# 10        93354.000000
# 11        87313.959187
# 12        84054.000000
# 13        87006.000000
# 14       102228.000000
# 15        84054.000000
# 16        91272.000000
# 17       111492.000000
# 18        95484.000000
# 19       114846.000000
# 20        87313.959187
# 21        87313.959187
# 22        63480.000000
# 23        87313.959187
# 24        90024.000000
# 25        82614.000000
# 26        87313.959187
# 27        48078.000000
# 28        87313.959187
# 29        72510.000000
#              ...
# 32782     84054.000000
# 32783     68616.000000
# 32784     84054.000000
# 32785     90024.000000
# 32786     87313.959187
# 32787     92274.000000
# 32788    114324.000000
# 32789     76266.000000
# 32790     87313.959187
# ...

# %%
plt.figure(figsize=(20, 15))
plt.hist(data.annual, bins=50, range=[0,250], label='price')
plt.title('Train "price" distribution', fontsize=15)
plt.xlabel('Price', fontsize=15)
plt.ylabel('Samples', fontsize=15)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.legend(fontsize=15)
plt.show()

# %%
from ggplot import mtcars
# Out:
# c:\python27\lib\site-packages\ggplot\utils.py:81: FutureWarning: pandas.tslib is deprecated and will be removed in a future version.
# You can access Timestamp as pandas.Timestamp
#   pd.tslib.Timestamp,
# c:\python27\lib\site-packages\ggplot\stats\smoothers.py:4: FutureWarning: The pandas.lib module is deprecated and will be removed in a future version. These are private functions and can be accessed from pandas._libs.lib instead
#   from pandas.lib import Timestamp
# c:\python27\lib\site-packages\statsmodels\compat\pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools

# %%
mtcars.head()
df =mtcars

# %%
df.head(3)
# Out:
#             name   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# 0      Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1     4
# 1  Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1     4
# 2     Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
#
#    carb
# 0     4
# 1     4
# 2     1

# %%
df.set_index('name', inplace=True)

# %%
df.tail()
# Out:
#                  mpg  cyl   disp   hp  drat     wt  qsec  vs  am  gear  carb
# name
# Lotus Europa    30.4    4   95.1  113  3.77  1.513  16.9   1   1     5     2
# Ford Pantera L  15.8    8  351.0  264  4.22  3.170  14.5   0   1     5     4
# Ferrari Dino    19.7    6  145.0  175  3.62  2.770  15.5   0   1     5     6
# Maserati Bora   15.0    8  301.0  335  3.54  3.570  14.6   0   1     5     8
# Volvo 142E      21.4    4  121.0  109  4.11  2.780  18.6   1   1     4     2

# %%
print df.index
# Out:
# Index([u'Mazda RX4', u'Mazda RX4 Wag', u'Datsun 710', u'Hornet 4 Drive',
#        u'Hornet Sportabout', u'Valiant', u'Duster 360', u'Merc 240D',
#        u'Merc 230', u'Merc 280', u'Merc 280C', u'Merc 450SE', u'Merc 450SL',
#        u'Merc 450SLC', u'Cadillac Fleetwood', u'Lincoln Continental',
#        u'Chrysler Imperial', u'Fiat 128', u'Honda Civic', u'Toyota Corolla',
#        u'Toyota Corona', u'Dodge Challenger', u'AMC Javelin', u'Camaro Z28',
#        u'Pontiac Firebird', u'Fiat X1-9', u'Porsche 914-2', u'Lotus Europa',
#        u'Ford Pantera L', u'Ferrari Dino', u'Maserati Bora', u'Volvo 142E'],
#       dtype='object', name=u'name')

# %%
print df.columns
# Out:
# Index([u'mpg', u'cyl', u'disp', u'hp', u'drat', u'wt', u'qsec', u'vs', u'am',
#        u'gear', u'carb'],
#       dtype='object')

# %%
a=df.iloc[:,0:5].describe()
print a
# Out:
#              mpg        cyl        disp          hp       drat
# count  32.000000  32.000000   32.000000   32.000000  32.000000
# mean   20.090625   6.187500  230.721875  146.687500   3.596563
# std     6.026948   1.785922  123.938694   68.562868   0.534679
# min    10.400000   4.000000   71.100000   52.000000   2.760000
# 25%    15.425000   4.000000  120.825000   96.500000   3.080000
# 50%    19.200000   6.000000  196.300000  123.000000   3.695000
# 75%    22.800000   8.000000  326.000000  180.000000   3.920000
# max    33.900000   8.000000  472.000000  335.000000   4.930000

# %%
df.index
# Out:
# Index([u'Mazda RX4', u'Mazda RX4 Wag', u'Datsun 710', u'Hornet 4 Drive',
#        u'Hornet Sportabout', u'Valiant', u'Duster 360', u'Merc 240D',
#        u'Merc 230', u'Merc 280', u'Merc 280C', u'Merc 450SE', u'Merc 450SL',
#        u'Merc 450SLC', u'Cadillac Fleetwood', u'Lincoln Continental',
#        u'Chrysler Imperial', u'Fiat 128', u'Honda Civic', u'Toyota Corolla',
#        u'Toyota Corona', u'Dodge Challenger', u'AMC Javelin', u'Camaro Z28',
#        u'Pontiac Firebird', u'Fiat X1-9', u'Porsche 914-2', u'Lotus Europa',
#        u'Ford Pantera L', u'Ferrari Dino', u'Maserati Bora', u'Volvo 142E'],
#       dtype='object', name=u'name')

# %%
np.mean(a, axis=0).index
# Out:
# Index([u'mpg', u'cyl', u'disp', u'hp', u'drat'], dtype='object')

# %%
df[df.mpg>10]
# Out:
#                       mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# name
# Mazda RX4            21.0    6  160.0  110  3.90  2.620  16.46   0   1     4
# Mazda RX4 Wag        21.0    6  160.0  110  3.90  2.875  17.02   0   1     4
# Datsun 710           22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
# Hornet 4 Drive       21.4    6  258.0  110  3.08  3.215  19.44   1   0     3
# Hornet Sportabout    18.7    8  360.0  175  3.15  3.440  17.02   0   0     3
# Valiant              18.1    6  225.0  105  2.76  3.460  20.22   1   0     3
# Duster 360           14.3    8  360.0  245  3.21  3.570  15.84   0   0     3
# Merc 240D            24.4    4  146.7   62  3.69  3.190  20.00   1   0     4
# Merc 230             22.8    4  140.8   95  3.92  3.150  22.90   1   0     4
# Merc 280             19.2    6  167.6  123  3.92  3.440  18.30   1   0     4
# Merc 280C            17.8    6  167.6  123  3.92  3.440  18.90   1   0     4
# ...

# %%
df.dtypes
# Out:
# mpg     float64
# cyl       int64
# disp    float64
# hp        int64
# drat    float64
# wt      float64
# qsec    float64
# vs        int64
# am        int64
# gear      int64
# carb      int64
# dtype: object

# %%
group = df["disp"].groupby(axis=1,level='mpg')
plot(kind="box",figsize=(9,9))
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-fe212fb24003> in <module>()
# ----> 1 group = df["disp"].groupby(axis=1,level='mpg')
#       2 plot(kind="box",figsize=(9,9))
#       3 plt.show()
#
# NameError: name 'df' is not defined

# %%
df["disp"].plot(kind="box", figsize=(9,9))
plt.show()

# %%
df["disp"].hist( figsize=(9,9))
plt.show()

# %%
df.plot(kind='density',figsize=(10,10),
            xlim=(-10,10))
plt.show()

# %%
df.plot(kind="bar", figsize=(8,8),stacked=True)
df.plot(kind="bar", figsize=(8,8),stacked=False)
plt.show()

# %%
df.plot(kind="scatter",     # Create a scatterplot
              x="cyl",          # Put carat on the x axis
              y="mpg",          # Put price on the y axis
              figsize=(10,10),
              ylim=(0,20000))
plt.show()

# %%
df.skew()
# Out:
# mpg     0.672377
# cyl    -0.192261
# disp    0.420233
# hp      0.799407
# drat    0.292780
# wt      0.465916
# qsec    0.406347
# vs      0.264542
# am      0.400809
# gear    0.582309
# carb    1.157091
# dtype: float64

# %%
from scipy  import stats as st

# %%
fit= st.norm.pdf(x=df.disp,mean=230)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-469-e42c21925ecb> in <module>()
# ----> 1 fit= st.norm.pdf(x=df.disp,mean=230)
#
# c:\python27\lib\site-packages\scipy\stats\_distn_infrastructure.pyc in pdf(self, x, *args, **kwds)
#    1646
#    1647         """
# -> 1648         args, loc, scale = self._parse_args(*args, **kwds)
#    1649         x, loc, scale = map(asarray, (x, loc, scale))
#    1650         args = tuple(map(asarray, args))
#
# TypeError: _parse_args() got an unexpected keyword argument 'mean'

# %%
print np.mean(df.disp)
print np.std(df.disp)
# Out:
# 230.721875
# 121.98678139

# %%
#population data
population_ages1 = stats.poisson.rvs(loc=18, mu=35, size=150000)
population_ages2 = stats.poisson.rvs(loc=18, mu=10, size=100000)
population_ages= np.concatenate((population_ages1, population_ages2))
#sample from population
sample_ages = np.random.choice(a= population_ages,size=500)     
population_ages.mean()
# Out:
# 43.008763999999999

# %%
sample_ages.mean()
# Out:
# 43.265999999999998

# %%
import random
random.seed(10)
population_races = (["white"]*100000) + (["black"]*50000) +\
                   (["hispanic"]*50000) + (["asian"]*25000) +\
                   (["other"]*25000)

# %%
set(population_races)
# Out:
# {'asian', 'black', 'hispanic', 'other', 'white'}

# %%
pd.DataFrame(population_ages).hist(bins=100,figsize=(9,9))
plt.show()
print( stats.skew(population_ages) )
# Out:
# -0.117684447351

# %%
pd.DataFrame(sample_ages).hist(bins=58,
                                  range=(17.5,75.5),
                                  figsize=(9,9))
plt.show()
print( stats.skew(sample_ages) )
# Out:
# -0.171496166925

# %%
#central limit therom
#means of the sample from the population is again  normaly distributed
point_estimates = []         # Make empty list to hold point estimates

for x in range(200):         # Generate 200 samples
    sample = np.random.choice(a= population_ages, size=500)
    point_estimates.append( sample.mean() )
    
pd.DataFrame(point_estimates).plot(kind="density",  # Plot sample mean density
                                   figsize=(9,9),
                                   xlim=(41,45))   
plt.show()

# %%
np.array(point_estimates).mean()
# Out:
# 43.050399999999989
